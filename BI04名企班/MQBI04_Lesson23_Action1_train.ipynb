# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/L23AssignmentCode/")

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null !apt-get update -qq 2>&1 > /dev/null !apt-get -y install -qq google-drive-ocamlfuse fuse from google.colab import auth auth.authenticate_user() from oauth2client.client import GoogleCredentials creds = GoogleCredentials.get_application_default() import getpass !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} &1 | grep URL vcode = getpass.getpass() !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `apt-get install -y -qq software-properties-common python-software-properties module-init-tools !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null !apt-get update -qq 2>&1 > /dev/null !apt-get -y install -qq google-drive-ocamlfuse fuse from google.colab import auth auth.authenticate_user() from oauth2client.client import GoogleCredentials creds = GoogleCredentials.get_application_default() import getpass !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} &1 | grep URL vcode = getpass.getpass() !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}'

# %%
# 训练五子棋AI
from __future__ import print_function
import random
import numpy as np
from collections import defaultdict, deque  # deque 是一个双端队列
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure  # 随机走子策略的AI
from mcts_alphaZero import MCTSPlayer  # AlphaGo方式的AI
from policy_value_net_pytorch import PolicyValueNet  # Pytorch


class TrainPipeline():
    def __init__(self, init_model=None):
        # 设置棋盘和游戏的参数
        self.board_width = 10
        self.board_height = 10
        self.n_in_row = 5
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # 设置训练参数
        self.learn_rate = 2e-3  # 基准学习率
        self.lr_multiplier = 1.0  # 基于KL自动调整学习倍速
        self.temp = 1.0  # 温度参数
        self.n_playout = 400  # 每下一步棋，模拟的步骤数
        self.c_puct = 5  # exploitation和exploration之间的折中系数
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        # 使用 deque 创建一个双端队列
        self.data_buffer = deque(maxlen=self.buffer_size)  
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02  # 早停检查
        self.check_freq = 50  # 每50次检查一次，策略价值网络是否更新
        self.game_batch_num = 500  # 训练多少个epoch
        self.best_win_ratio = 0.0  # 当前最佳胜率，用他来判断是否有更好的模型
        # 弱AI（纯MCTS）模拟步数，用于给训练的策略AI提供对手
        self.pure_mcts_playout_num = 1000
        if init_model:
            # 通过init_model设置策略网络
            self.policy_value_net = PolicyValueNet(self.board_width,
                                                   self.board_height,
                                                   model_file=init_model)
        else:
            # 训练一个新的策略网络
            self.policy_value_net = PolicyValueNet(self.board_width,
                                                   self.board_height)
        # AI Player，设置is_selfplay=1 自我对弈，因为是在进行训练
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)

    def get_equi_data(self, play_data):
        """通过旋转和翻转增加数据集, play_data: [(state, mcts_prob, winner_z), ..., ...]
        """
        extend_data = []
        for state, mcts_porb, winner in play_data:
            # 在4个方向上进行expand，每个方向都进行旋转，水平翻转
            for i in [1, 2, 3, 4]:
                # 逆时针旋转
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(
                    np.flipud(
                        mcts_porb.reshape(self.board_height,
                                          self.board_width)), i)
                extend_data.append(
                    (equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
                # 水平翻转
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append(
                    (equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
        return extend_data

    def collect_selfplay_data(self, n_games=1):
        """收集自我对弈数据，用于训练"""
        for i in range(n_games):
            # 与MCTS Player进行对弈
            winner, play_data = self.game.start_self_play(self.mcts_player,
                                                          temp=self.temp)
            play_data = list(play_data)[:]
            # 保存下了多少步
            self.episode_len = len(play_data)
            # 增加数据 play_data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)

    # 更新策略网络
    def policy_update(self):
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        # 保存更新前的old_probs, old_v
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            # 每次训练，调整参数，返回loss和entropy
            loss, entropy = self.policy_value_net.train_step(
                state_batch, mcts_probs_batch, winner_batch,
                self.learn_rate * self.lr_multiplier)
            # 输入状态，得到行动的可能性和状态值，按照batch进行输入
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            # 计算更新前后两次的loss差
            kl = np.mean(
                np.sum(old_probs *
                       (np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                       axis=1))
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # 动态调整学习倍率 lr_multiplier
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}").format(kl, self.lr_multiplier, loss,
                                                  entropy, explained_var_old,
                                                  explained_var_new))
        return loss, entropy

    # 用于评估训练网络的质量，评估一共10场play，返回比赛胜率（赢1分、输0分、平0.5分）
    def policy_evaluate(self, n_games=10):
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct,
                                         n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5,
                                     n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            # AI和弱AI（纯MCTS）对弈，不需要可视化 is_shown=0，双方轮流职黑 start_player=i % 2
            winner = self.game.start_play(current_mcts_player,
                                          pure_mcts_player,
                                          start_player=i % 2,
                                          is_shown=0)
            win_cnt[winner] += 1
        # 计算胜率，平手计为0.5分
        win_ratio = 1.0 * (win_cnt[1] + 0.5 * win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
            self.pure_mcts_playout_num, win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        # 开始训练
        try:
            # 训练game_batch_num次，每个batch比赛play_batch_size场
            for i in range(self.game_batch_num):
                # 收集自我对弈数据
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(
                    i + 1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # 判断当前模型的表现，保存最优模型
                if (i + 1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i + 1))
                    win_ratio = self.policy_evaluate()
                    # 保存当前策略
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("发现新的最优策略，进行策略更新")
                        self.best_win_ratio = win_ratio
                        # 更新最优策略
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0
                                and self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')


if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# /content/drive/My Drive/Colab Notebooks/L23AssignmentCode/policy_value_net_pytorch.py:45: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# batch i:1, episode_len:39
# batch i:2, episode_len:44
# kl:0.01521,lr_multiplier:1.000,loss:5.589372158050537,entropy:4.594301700592041,explained_var_old:0.000,explained_var_new:-0.000
# batch i:3, episode_len:58
# kl:0.01501,lr_multiplier:1.000,loss:5.574063777923584,entropy:4.561339378356934,explained_var_old:0.000,explained_var_new:0.028
# batch i:4, episode_len:15
# kl:0.00528,lr_multiplier:1.500,loss:5.519227981567383,entropy:4.58284854888916,explained_var_old:0.019,explained_var_new:0.105
# batch i:5, episode_len:37
# kl:0.01918,lr_multiplier:1.500,loss:5.510734558105469,entropy:4.5026092529296875,explained_var_old:0.027,explained_var_new:0.060
# batch i:6, episode_len:34
# kl:0.01505,lr_multiplier:1.500,loss:5.450872421264648,entropy:4.572805881500244,explained_var_old:0.068,explained_var_new:0.109
# batch i:7, episode_len:32
# kl:0.02241,lr_multiplier:1.500,loss:5.275301456451416,entropy:4.533483505249023,explained_var_old:0.137,explained_var_new:0.279
# batch i:8, episode_len:40
# kl:0.02899,lr_multiplier:1.500,loss:5.296050548553467,entropy:4.548683166503906,explained_var_old:0.039,explained_var_new:0.282
# batch i:9, episode_len:47
# kl:0.04912,lr_multiplier:1.000,loss:5.219123840332031,entropy:4.4040913581848145,explained_var_old:0.169,explained_var_new:0.264
# batch i:10, episode_len:50
# kl:0.04173,lr_multiplier:0.667,loss:5.082273960113525,entropy:4.468178749084473,explained_var_old:0.313,explained_var_new:0.382
# batch i:11, episode_len:19
# kl:0.01323,lr_multiplier:0.667,loss:5.090785026550293,entropy:4.4535932540893555,explained_var_old:0.299,explained_var_new:0.360
# batch i:12, episode_len:51
# kl:0.02652,lr_multiplier:0.667,loss:5.22089958190918,entropy:4.412894248962402,explained_var_old:0.123,explained_var_new:0.203
# batch i:13, episode_len:28
# kl:0.02723,lr_multiplier:0.667,loss:5.189291954040527,entropy:4.407641887664795,explained_var_old:0.147,explained_var_new:0.211
# batch i:14, episode_len:41
# kl:0.02021,lr_multiplier:0.667,loss:5.130934238433838,entropy:4.392222881317139,explained_var_old:0.211,explained_var_new:0.264
# batch i:15, episode_len:50
# kl:0.02851,lr_multiplier:0.667,loss:5.189382553100586,entropy:4.356710433959961,explained_var_old:0.122,explained_var_new:0.179
# batch i:16, episode_len:43
# kl:0.02853,lr_multiplier:0.667,loss:5.1808366775512695,entropy:4.3859758377075195,explained_var_old:0.161,explained_var_new:0.193
# batch i:17, episode_len:44
# kl:0.02283,lr_multiplier:0.667,loss:5.1101837158203125,entropy:4.315401077270508,explained_var_old:0.158,explained_var_new:0.229
# batch i:18, episode_len:28
# kl:0.03243,lr_multiplier:0.667,loss:5.045334339141846,entropy:4.349053859710693,explained_var_old:0.216,explained_var_new:0.280
# batch i:19, episode_len:29
# kl:0.04270,lr_multiplier:0.444,loss:5.02932071685791,entropy:4.281899929046631,explained_var_old:0.228,explained_var_new:0.286
# batch i:20, episode_len:23
# kl:0.02066,lr_multiplier:0.444,loss:5.017314434051514,entropy:4.28035306930542,explained_var_old:0.229,explained_var_new:0.263
# batch i:21, episode_len:44
# kl:0.03265,lr_multiplier:0.444,loss:4.969961166381836,entropy:4.243195056915283,explained_var_old:0.240,explained_var_new:0.287
# batch i:22, episode_len:33
# kl:0.02712,lr_multiplier:0.444,loss:5.029428482055664,entropy:4.324947357177734,explained_var_old:0.222,explained_var_new:0.256
# batch i:23, episode_len:24
# kl:0.01928,lr_multiplier:0.444,loss:5.031355381011963,entropy:4.284660816192627,explained_var_old:0.214,explained_var_new:0.249
# batch i:24, episode_len:21
# kl:0.02323,lr_multiplier:0.444,loss:5.019036293029785,entropy:4.245911598205566,explained_var_old:0.170,explained_var_new:0.217
# batch i:25, episode_len:31
# kl:0.01963,lr_multiplier:0.444,loss:5.073948860168457,entropy:4.256596088409424,explained_var_old:0.112,explained_var_new:0.171
# batch i:26, episode_len:39
# kl:0.02474,lr_multiplier:0.444,loss:4.997541904449463,entropy:4.238394260406494,explained_var_old:0.178,explained_var_new:0.220
# batch i:27, episode_len:31
# kl:0.01719,lr_multiplier:0.444,loss:5.008832931518555,entropy:4.240962982177734,explained_var_old:0.163,explained_var_new:0.208
# batch i:28, episode_len:42
# kl:0.03172,lr_multiplier:0.444,loss:5.006654262542725,entropy:4.206495761871338,explained_var_old:0.171,explained_var_new:0.209
# batch i:29, episode_len:31
# kl:0.03038,lr_multiplier:0.444,loss:4.9620361328125,entropy:4.20487117767334,explained_var_old:0.207,explained_var_new:0.249
# batch i:30, episode_len:42
# kl:0.02463,lr_multiplier:0.444,loss:4.998660087585449,entropy:4.248506546020508,explained_var_old:0.197,explained_var_new:0.227
# batch i:31, episode_len:28
# kl:0.02923,lr_multiplier:0.444,loss:4.977539539337158,entropy:4.209859371185303,explained_var_old:0.169,explained_var_new:0.226
# batch i:32, episode_len:54
# kl:0.02735,lr_multiplier:0.444,loss:4.944841384887695,entropy:4.163817405700684,explained_var_old:0.198,explained_var_new:0.240
# batch i:33, episode_len:21
# kl:0.01769,lr_multiplier:0.444,loss:4.919395923614502,entropy:4.211734771728516,explained_var_old:0.236,explained_var_new:0.289
# batch i:34, episode_len:25
# kl:0.02427,lr_multiplier:0.444,loss:4.961785316467285,entropy:4.2061967849731445,explained_var_old:0.172,explained_var_new:0.223
# batch i:35, episode_len:39
# kl:0.01818,lr_multiplier:0.444,loss:4.896306991577148,entropy:4.206638336181641,explained_var_old:0.248,explained_var_new:0.300
# batch i:36, episode_len:28
# kl:0.01996,lr_multiplier:0.444,loss:4.976665019989014,entropy:4.209560394287109,explained_var_old:0.192,explained_var_new:0.233
# batch i:37, episode_len:31
# kl:0.02344,lr_multiplier:0.444,loss:4.856348514556885,entropy:4.180629253387451,explained_var_old:0.244,explained_var_new:0.295
# batch i:38, episode_len:27
# kl:0.02732,lr_multiplier:0.444,loss:4.829146385192871,entropy:4.091273784637451,explained_var_old:0.222,explained_var_new:0.282
# batch i:39, episode_len:42
# kl:0.02995,lr_multiplier:0.444,loss:4.93231201171875,entropy:4.183938980102539,explained_var_old:0.176,explained_var_new:0.213
# batch i:40, episode_len:41
# kl:0.03375,lr_multiplier:0.444,loss:4.902057647705078,entropy:4.10017728805542,explained_var_old:0.157,explained_var_new:0.204
# batch i:41, episode_len:28
# kl:0.03943,lr_multiplier:0.444,loss:4.888632774353027,entropy:4.131158828735352,explained_var_old:0.164,explained_var_new:0.225
# batch i:42, episode_len:23
# kl:0.02974,lr_multiplier:0.444,loss:4.825845718383789,entropy:4.081549644470215,explained_var_old:0.193,explained_var_new:0.240
# batch i:43, episode_len:46
# kl:0.03379,lr_multiplier:0.444,loss:4.800037384033203,entropy:4.018441200256348,explained_var_old:0.146,explained_var_new:0.214
# batch i:44, episode_len:40
# kl:0.03422,lr_multiplier:0.444,loss:4.885229110717773,entropy:4.095017433166504,explained_var_old:0.146,explained_var_new:0.202
# batch i:45, episode_len:38
# kl:0.02730,lr_multiplier:0.444,loss:4.822233200073242,entropy:4.0577216148376465,explained_var_old:0.122,explained_var_new:0.206
# batch i:46, episode_len:38
# kl:0.03547,lr_multiplier:0.444,loss:4.785311222076416,entropy:4.013401985168457,explained_var_old:0.113,explained_var_new:0.214
# batch i:47, episode_len:38
# kl:0.03853,lr_multiplier:0.444,loss:4.792684555053711,entropy:4.028017044067383,explained_var_old:0.207,explained_var_new:0.242
# batch i:48, episode_len:23
# kl:0.04226,lr_multiplier:0.296,loss:4.762716293334961,entropy:4.047146797180176,explained_var_old:0.184,explained_var_new:0.262
# batch i:49, episode_len:36
# kl:0.01421,lr_multiplier:0.296,loss:4.770833969116211,entropy:4.070028305053711,explained_var_old:0.222,explained_var_new:0.271
# batch i:50, episode_len:48
# kl:0.02701,lr_multiplier:0.296,loss:4.737785339355469,entropy:3.9652516841888428,explained_var_old:0.212,explained_var_new:0.275
# current self-play batch: 50
# num_playouts:1000, win: 2, lose: 8, tie:0
# 发现新的最优策略，进行策略更新
# batch i:51, episode_len:21
# kl:0.02600,lr_multiplier:0.296,loss:4.743555545806885,entropy:4.026932716369629,explained_var_old:0.241,explained_var_new:0.276
# batch i:52, episode_len:21
# kl:0.02396,lr_multiplier:0.296,loss:4.736627101898193,entropy:3.9769511222839355,explained_var_old:0.234,explained_var_new:0.262
# batch i:53, episode_len:21
# kl:0.02335,lr_multiplier:0.296,loss:4.704770565032959,entropy:4.020389080047607,explained_var_old:0.247,explained_var_new:0.298
# batch i:54, episode_len:28
# kl:0.01869,lr_multiplier:0.296,loss:4.696038246154785,entropy:4.000336647033691,explained_var_old:0.261,explained_var_new:0.294
# batch i:55, episode_len:29
# kl:0.02478,lr_multiplier:0.296,loss:4.707409858703613,entropy:4.0214762687683105,explained_var_old:0.247,explained_var_new:0.302
# batch i:56, episode_len:33
# kl:0.01714,lr_multiplier:0.296,loss:4.7764410972595215,entropy:4.016543865203857,explained_var_old:0.170,explained_var_new:0.210
# batch i:57, episode_len:16
# kl:0.02001,lr_multiplier:0.296,loss:4.674822807312012,entropy:3.9680426120758057,explained_var_old:0.261,explained_var_new:0.298
# batch i:58, episode_len:24
# kl:0.01675,lr_multiplier:0.296,loss:4.711845397949219,entropy:3.9819583892822266,explained_var_old:0.223,explained_var_new:0.263
# batch i:59, episode_len:52
# kl:0.02232,lr_multiplier:0.296,loss:4.709174156188965,entropy:3.9592671394348145,explained_var_old:0.196,explained_var_new:0.232
# batch i:60, episode_len:26
# kl:0.02288,lr_multiplier:0.296,loss:4.8456549644470215,entropy:4.018113136291504,explained_var_old:0.111,explained_var_new:0.153
# batch i:61, episode_len:37
# kl:0.02230,lr_multiplier:0.296,loss:4.738044738769531,entropy:3.9789247512817383,explained_var_old:0.166,explained_var_new:0.229
# batch i:62, episode_len:21
# kl:0.01869,lr_multiplier:0.296,loss:4.722418785095215,entropy:3.9608826637268066,explained_var_old:0.157,explained_var_new:0.209
# batch i:63, episode_len:31
# kl:0.01978,lr_multiplier:0.296,loss:4.683093547821045,entropy:3.9568440914154053,explained_var_old:0.228,explained_var_new:0.268
# batch i:64, episode_len:24
# kl:0.02176,lr_multiplier:0.296,loss:4.704891681671143,entropy:3.937652587890625,explained_var_old:0.187,explained_var_new:0.240
# batch i:65, episode_len:47
# kl:0.02034,lr_multiplier:0.296,loss:4.819599628448486,entropy:4.017996311187744,explained_var_old:0.149,explained_var_new:0.177
# batch i:66, episode_len:25
# kl:0.01679,lr_multiplier:0.296,loss:4.706092357635498,entropy:3.986961841583252,explained_var_old:0.174,explained_var_new:0.234
# batch i:67, episode_len:31
# kl:0.01556,lr_multiplier:0.296,loss:4.82078742980957,entropy:3.9729833602905273,explained_var_old:0.104,explained_var_new:0.155
# batch i:68, episode_len:34
# kl:0.02466,lr_multiplier:0.296,loss:4.67108678817749,entropy:3.9214797019958496,explained_var_old:0.201,explained_var_new:0.259
# batch i:69, episode_len:22
# kl:0.02022,lr_multiplier:0.296,loss:4.6566362380981445,entropy:3.924513339996338,explained_var_old:0.241,explained_var_new:0.282
# batch i:70, episode_len:54
# kl:0.02379,lr_multiplier:0.296,loss:4.713912010192871,entropy:3.931936264038086,explained_var_old:0.150,explained_var_new:0.196
# batch i:71, episode_len:34
# kl:0.02556,lr_multiplier:0.296,loss:4.671215534210205,entropy:3.9330625534057617,explained_var_old:0.200,explained_var_new:0.228
# batch i:72, episode_len:26
# kl:0.03206,lr_multiplier:0.296,loss:4.5994462966918945,entropy:3.8810315132141113,explained_var_old:0.237,explained_var_new:0.276
# batch i:73, episode_len:31
# kl:0.02454,lr_multiplier:0.296,loss:4.650068283081055,entropy:3.897214889526367,explained_var_old:0.206,explained_var_new:0.240
# batch i:74, episode_len:21
# kl:0.01984,lr_multiplier:0.296,loss:4.652167797088623,entropy:3.8951635360717773,explained_var_old:0.216,explained_var_new:0.243
# batch i:75, episode_len:19
# kl:0.02174,lr_multiplier:0.296,loss:4.574458122253418,entropy:3.8319151401519775,explained_var_old:0.232,explained_var_new:0.269
# batch i:76, episode_len:20
# kl:0.02021,lr_multiplier:0.296,loss:4.6631388664245605,entropy:3.8846054077148438,explained_var_old:0.160,explained_var_new:0.206
# batch i:77, episode_len:26
# kl:0.02394,lr_multiplier:0.296,loss:4.579400062561035,entropy:3.8644020557403564,explained_var_old:0.229,explained_var_new:0.274
# batch i:78, episode_len:49
# kl:0.02022,lr_multiplier:0.296,loss:4.661350250244141,entropy:3.849158763885498,explained_var_old:0.136,explained_var_new:0.181
# batch i:79, episode_len:22
# kl:0.02139,lr_multiplier:0.296,loss:4.631155014038086,entropy:3.840634346008301,explained_var_old:0.167,explained_var_new:0.201
# batch i:80, episode_len:40
# kl:0.03317,lr_multiplier:0.296,loss:4.626300811767578,entropy:3.8523623943328857,explained_var_old:0.199,explained_var_new:0.247
# batch i:81, episode_len:42
# kl:0.02443,lr_multiplier:0.296,loss:4.623040199279785,entropy:3.83819580078125,explained_var_old:0.164,explained_var_new:0.211
# batch i:82, episode_len:46
# kl:0.03170,lr_multiplier:0.296,loss:4.594037055969238,entropy:3.8270604610443115,explained_var_old:0.167,explained_var_new:0.232
# batch i:83, episode_len:42
# kl:0.02862,lr_multiplier:0.296,loss:4.471877574920654,entropy:3.7952258586883545,explained_var_old:0.234,explained_var_new:0.314
# batch i:84, episode_len:29
# kl:0.05101,lr_multiplier:0.198,loss:4.430328369140625,entropy:3.759822368621826,explained_var_old:0.248,explained_var_new:0.327
# batch i:85, episode_len:34
# kl:0.01833,lr_multiplier:0.198,loss:4.4986796379089355,entropy:3.7683255672454834,explained_var_old:0.254,explained_var_new:0.296
# batch i:86, episode_len:20
# kl:0.02438,lr_multiplier:0.198,loss:4.432101249694824,entropy:3.7820799350738525,explained_var_old:0.294,explained_var_new:0.338
# batch i:87, episode_len:43
# kl:0.02183,lr_multiplier:0.198,loss:4.507667064666748,entropy:3.7867143154144287,explained_var_old:0.201,explained_var_new:0.261
# batch i:88, episode_len:33
# kl:0.01868,lr_multiplier:0.198,loss:4.453031063079834,entropy:3.7700815200805664,explained_var_old:0.244,explained_var_new:0.268
# batch i:89, episode_len:28
# kl:0.02328,lr_multiplier:0.198,loss:4.416836738586426,entropy:3.686349630355835,explained_var_old:0.245,explained_var_new:0.298
# batch i:90, episode_len:35
# kl:0.02287,lr_multiplier:0.198,loss:4.492626190185547,entropy:3.7448697090148926,explained_var_old:0.213,explained_var_new:0.260
# batch i:91, episode_len:26
# kl:0.01965,lr_multiplier:0.198,loss:4.484070777893066,entropy:3.753416061401367,explained_var_old:0.229,explained_var_new:0.264
# batch i:92, episode_len:14
# kl:0.02459,lr_multiplier:0.198,loss:4.4489970207214355,entropy:3.746410846710205,explained_var_old:0.261,explained_var_new:0.299
# batch i:93, episode_len:29
# kl:0.01817,lr_multiplier:0.198,loss:4.427390098571777,entropy:3.705288887023926,explained_var_old:0.247,explained_var_new:0.281
# batch i:94, episode_len:38
# kl:0.01657,lr_multiplier:0.198,loss:4.531291484832764,entropy:3.752068519592285,explained_var_old:0.167,explained_var_new:0.221
# batch i:95, episode_len:23
# kl:0.01737,lr_multiplier:0.198,loss:4.428600788116455,entropy:3.688880205154419,explained_var_old:0.238,explained_var_new:0.281
# batch i:96, episode_len:32
# kl:0.01737,lr_multiplier:0.198,loss:4.3654890060424805,entropy:3.7037951946258545,explained_var_old:0.283,explained_var_new:0.331
# batch i:97, episode_len:29
# kl:0.01761,lr_multiplier:0.198,loss:4.297185897827148,entropy:3.6943514347076416,explained_var_old:0.332,explained_var_new:0.382
# batch i:98, episode_len:43
# kl:0.01970,lr_multiplier:0.198,loss:4.3430681228637695,entropy:3.6941285133361816,explained_var_old:0.282,explained_var_new:0.340
# batch i:99, episode_len:41
# kl:0.01681,lr_multiplier:0.198,loss:4.338747978210449,entropy:3.652454137802124,explained_var_old:0.237,explained_var_new:0.307
# batch i:100, episode_len:24
# kl:0.02111,lr_multiplier:0.198,loss:4.37769889831543,entropy:3.679525852203369,explained_var_old:0.210,explained_var_new:0.296
# current self-play batch: 100
# num_playouts:1000, win: 5, lose: 5, tie:0
# 发现新的最优策略，进行策略更新
# batch i:101, episode_len:30
# kl:0.02329,lr_multiplier:0.198,loss:4.328652381896973,entropy:3.648902416229248,explained_var_old:0.259,explained_var_new:0.321
# batch i:102, episode_len:18
# kl:0.02327,lr_multiplier:0.198,loss:4.374569892883301,entropy:3.667799711227417,explained_var_old:0.237,explained_var_new:0.320
# batch i:103, episode_len:30
# kl:0.02476,lr_multiplier:0.198,loss:4.382336616516113,entropy:3.6674625873565674,explained_var_old:0.234,explained_var_new:0.279
# batch i:104, episode_len:23
# kl:0.03022,lr_multiplier:0.198,loss:4.269556045532227,entropy:3.6397252082824707,explained_var_old:0.318,explained_var_new:0.379
# batch i:105, episode_len:42
# kl:0.03013,lr_multiplier:0.198,loss:4.2718353271484375,entropy:3.653817892074585,explained_var_old:0.277,explained_var_new:0.332
# batch i:106, episode_len:35
# kl:0.02760,lr_multiplier:0.198,loss:4.256366729736328,entropy:3.625661849975586,explained_var_old:0.290,explained_var_new:0.357
# batch i:107, episode_len:21
# kl:0.02954,lr_multiplier:0.198,loss:4.257623672485352,entropy:3.6267123222351074,explained_var_old:0.293,explained_var_new:0.372
# batch i:108, episode_len:53
# kl:0.02719,lr_multiplier:0.198,loss:4.258143424987793,entropy:3.6074628829956055,explained_var_old:0.248,explained_var_new:0.325
# batch i:109, episode_len:29
# kl:0.02898,lr_multiplier:0.198,loss:4.2593793869018555,entropy:3.596553087234497,explained_var_old:0.272,explained_var_new:0.350
# batch i:110, episode_len:35
# kl:0.02352,lr_multiplier:0.198,loss:4.252077102661133,entropy:3.559943199157715,explained_var_old:0.231,explained_var_new:0.310
# batch i:111, episode_len:22
# kl:0.02944,lr_multiplier:0.198,loss:4.274223804473877,entropy:3.607513427734375,explained_var_old:0.279,explained_var_new:0.337
# batch i:112, episode_len:24
# kl:0.02657,lr_multiplier:0.198,loss:4.2436604499816895,entropy:3.5982933044433594,explained_var_old:0.282,explained_var_new:0.337
# batch i:113, episode_len:43
# kl:0.03852,lr_multiplier:0.198,loss:4.246776580810547,entropy:3.553532600402832,explained_var_old:0.272,explained_var_new:0.331
# batch i:114, episode_len:37
# kl:0.04886,lr_multiplier:0.132,loss:4.1780104637146,entropy:3.628356695175171,explained_var_old:0.390,explained_var_new:0.437
# batch i:115, episode_len:42
# kl:0.03504,lr_multiplier:0.132,loss:4.26718282699585,entropy:3.5741071701049805,explained_var_old:0.255,explained_var_new:0.333
# batch i:116, episode_len:20
# kl:0.02580,lr_multiplier:0.132,loss:4.1385321617126465,entropy:3.581813335418701,explained_var_old:0.381,explained_var_new:0.439
# batch i:117, episode_len:19
# kl:0.01490,lr_multiplier:0.132,loss:4.152745723724365,entropy:3.589479446411133,explained_var_old:0.351,explained_var_new:0.400
# batch i:118, episode_len:42
# kl:0.01816,lr_multiplier:0.132,loss:4.231597423553467,entropy:3.5941920280456543,explained_var_old:0.270,explained_var_new:0.344
# batch i:119, episode_len:18
# kl:0.02371,lr_multiplier:0.132,loss:4.1158342361450195,entropy:3.5684428215026855,explained_var_old:0.390,explained_var_new:0.425
# batch i:120, episode_len:16
# kl:0.02511,lr_multiplier:0.132,loss:4.118835926055908,entropy:3.554281711578369,explained_var_old:0.379,explained_var_new:0.422
# batch i:121, episode_len:29
# kl:0.02231,lr_multiplier:0.132,loss:4.17960786819458,entropy:3.526961088180542,explained_var_old:0.341,explained_var_new:0.404
# batch i:122, episode_len:12
# kl:0.03828,lr_multiplier:0.132,loss:4.137568473815918,entropy:3.5559208393096924,explained_var_old:0.326,explained_var_new:0.403
# batch i:123, episode_len:28
# kl:0.01362,lr_multiplier:0.132,loss:4.065115451812744,entropy:3.5949487686157227,explained_var_old:0.491,explained_var_new:0.548
# batch i:124, episode_len:15
# kl:0.03975,lr_multiplier:0.132,loss:4.111170768737793,entropy:3.519996166229248,explained_var_old:0.385,explained_var_new:0.431
# batch i:125, episode_len:42
# kl:0.03256,lr_multiplier:0.132,loss:4.170350074768066,entropy:3.553384780883789,explained_var_old:0.288,explained_var_new:0.351
# batch i:126, episode_len:17
# kl:0.01887,lr_multiplier:0.132,loss:4.181516647338867,entropy:3.555330991744995,explained_var_old:0.340,explained_var_new:0.378
# batch i:127, episode_len:22
# kl:0.01673,lr_multiplier:0.132,loss:4.045924186706543,entropy:3.5446817874908447,explained_var_old:0.418,explained_var_new:0.471
# batch i:128, episode_len:29
# kl:0.00992,lr_multiplier:0.198,loss:4.135121822357178,entropy:3.522502899169922,explained_var_old:0.333,explained_var_new:0.380
# batch i:129, episode_len:20
# kl:0.01583,lr_multiplier:0.198,loss:4.11159610748291,entropy:3.561401128768921,explained_var_old:0.380,explained_var_new:0.465
# batch i:130, episode_len:34
# kl:0.01856,lr_multiplier:0.198,loss:3.9920740127563477,entropy:3.4707984924316406,explained_var_old:0.382,explained_var_new:0.445
# batch i:131, episode_len:25
# kl:0.02048,lr_multiplier:0.198,loss:4.049422740936279,entropy:3.4663212299346924,explained_var_old:0.357,explained_var_new:0.429
# batch i:132, episode_len:25
# kl:0.02570,lr_multiplier:0.198,loss:4.121491432189941,entropy:3.4591064453125,explained_var_old:0.301,explained_var_new:0.366
# batch i:133, episode_len:19
# kl:0.02448,lr_multiplier:0.198,loss:4.156184196472168,entropy:3.526185989379883,explained_var_old:0.296,explained_var_new:0.366
# batch i:134, episode_len:18
# kl:0.02483,lr_multiplier:0.198,loss:4.001014709472656,entropy:3.5042967796325684,explained_var_old:0.401,explained_var_new:0.466
# batch i:135, episode_len:35
# kl:0.02650,lr_multiplier:0.198,loss:4.07790470123291,entropy:3.507999897003174,explained_var_old:0.369,explained_var_new:0.427
# batch i:136, episode_len:41
# kl:0.02217,lr_multiplier:0.198,loss:4.01053524017334,entropy:3.478534698486328,explained_var_old:0.394,explained_var_new:0.451
# batch i:137, episode_len:23
# kl:0.03198,lr_multiplier:0.198,loss:4.023674011230469,entropy:3.4495935440063477,explained_var_old:0.381,explained_var_new:0.447
# batch i:138, episode_len:29
# kl:0.02180,lr_multiplier:0.198,loss:4.0197577476501465,entropy:3.4971516132354736,explained_var_old:0.382,explained_var_new:0.443
# batch i:139, episode_len:26
# kl:0.02158,lr_multiplier:0.198,loss:3.9898838996887207,entropy:3.4527313709259033,explained_var_old:0.359,explained_var_new:0.425
# batch i:140, episode_len:28
# kl:0.02204,lr_multiplier:0.198,loss:4.054762363433838,entropy:3.4235401153564453,explained_var_old:0.321,explained_var_new:0.397
# batch i:141, episode_len:14
# kl:0.02822,lr_multiplier:0.198,loss:3.973247766494751,entropy:3.429948091506958,explained_var_old:0.343,explained_var_new:0.412
# batch i:142, episode_len:23
# kl:0.02882,lr_multiplier:0.198,loss:3.870678424835205,entropy:3.36873459815979,explained_var_old:0.414,explained_var_new:0.474
# batch i:143, episode_len:20
# kl:0.03249,lr_multiplier:0.198,loss:3.9222054481506348,entropy:3.389516592025757,explained_var_old:0.379,explained_var_new:0.440
# batch i:144, episode_len:31
# kl:0.02000,lr_multiplier:0.198,loss:3.9097299575805664,entropy:3.3681416511535645,explained_var_old:0.413,explained_var_new:0.466
# batch i:145, episode_len:31
# kl:0.03328,lr_multiplier:0.198,loss:3.923518180847168,entropy:3.3428637981414795,explained_var_old:0.382,explained_var_new:0.442
# batch i:146, episode_len:14
# kl:0.02731,lr_multiplier:0.198,loss:3.898909568786621,entropy:3.314781904220581,explained_var_old:0.365,explained_var_new:0.424
# batch i:147, episode_len:22
# kl:0.02659,lr_multiplier:0.198,loss:3.8870205879211426,entropy:3.36377215385437,explained_var_old:0.379,explained_var_new:0.426
# batch i:148, episode_len:33
# kl:0.02520,lr_multiplier:0.198,loss:3.939531087875366,entropy:3.379502058029175,explained_var_old:0.349,explained_var_new:0.401
# batch i:149, episode_len:20
# kl:0.02655,lr_multiplier:0.198,loss:3.9214353561401367,entropy:3.3279709815979004,explained_var_old:0.328,explained_var_new:0.389
# batch i:150, episode_len:23
# kl:0.04191,lr_multiplier:0.132,loss:3.9630725383758545,entropy:3.329002618789673,explained_var_old:0.291,explained_var_new:0.369
# current self-play batch: 150
# num_playouts:1000, win: 3, lose: 7, tie:0
# batch i:151, episode_len:22
# kl:0.01526,lr_multiplier:0.132,loss:3.9735071659088135,entropy:3.407561779022217,explained_var_old:0.313,explained_var_new:0.365
# batch i:152, episode_len:25
# kl:0.02417,lr_multiplier:0.132,loss:3.9170713424682617,entropy:3.3094871044158936,explained_var_old:0.347,explained_var_new:0.376
# batch i:153, episode_len:17
# kl:0.01167,lr_multiplier:0.132,loss:3.9225690364837646,entropy:3.281010627746582,explained_var_old:0.295,explained_var_new:0.373
# batch i:154, episode_len:23
# kl:0.00997,lr_multiplier:0.198,loss:3.9025518894195557,entropy:3.2933263778686523,explained_var_old:0.335,explained_var_new:0.374
# batch i:155, episode_len:27
# kl:0.02354,lr_multiplier:0.198,loss:3.9681081771850586,entropy:3.3322343826293945,explained_var_old:0.311,explained_var_new:0.358
# batch i:156, episode_len:17
# kl:0.02981,lr_multiplier:0.198,loss:3.9839673042297363,entropy:3.3102853298187256,explained_var_old:0.259,explained_var_new:0.315
# batch i:157, episode_len:15
# kl:0.04971,lr_multiplier:0.132,loss:3.9110465049743652,entropy:3.2512683868408203,explained_var_old:0.293,explained_var_new:0.334
# batch i:158, episode_len:19
# kl:0.03470,lr_multiplier:0.132,loss:3.875135898590088,entropy:3.283651828765869,explained_var_old:0.339,explained_var_new:0.368
# batch i:159, episode_len:31
# kl:0.04512,lr_multiplier:0.088,loss:3.914658308029175,entropy:3.2082157135009766,explained_var_old:0.281,explained_var_new:0.325
# batch i:160, episode_len:26
# kl:0.03694,lr_multiplier:0.088,loss:3.8853561878204346,entropy:3.2847371101379395,explained_var_old:0.327,explained_var_new:0.360
# batch i:161, episode_len:19
# kl:0.01657,lr_multiplier:0.088,loss:3.9492807388305664,entropy:3.2922005653381348,explained_var_old:0.267,explained_var_new:0.310
# batch i:162, episode_len:35
# kl:0.00792,lr_multiplier:0.132,loss:3.930997371673584,entropy:3.2644290924072266,explained_var_old:0.323,explained_var_new:0.350
# batch i:163, episode_len:33
# kl:0.02076,lr_multiplier:0.132,loss:3.903130531311035,entropy:3.25614070892334,explained_var_old:0.262,explained_var_new:0.302
# batch i:164, episode_len:37
# kl:0.01394,lr_multiplier:0.132,loss:3.923912525177002,entropy:3.197110652923584,explained_var_old:0.207,explained_var_new:0.254
# batch i:165, episode_len:14
# kl:0.01684,lr_multiplier:0.132,loss:3.8262789249420166,entropy:3.2592196464538574,explained_var_old:0.313,explained_var_new:0.336
# batch i:166, episode_len:39
# kl:0.02398,lr_multiplier:0.132,loss:3.7725677490234375,entropy:3.178697109222412,explained_var_old:0.367,explained_var_new:0.397
# batch i:167, episode_len:25
# kl:0.01669,lr_multiplier:0.132,loss:3.861147403717041,entropy:3.1479852199554443,explained_var_old:0.295,explained_var_new:0.322
# batch i:168, episode_len:21
# kl:0.01363,lr_multiplier:0.132,loss:3.6948628425598145,entropy:3.085444927215576,explained_var_old:0.355,explained_var_new:0.374
# batch i:169, episode_len:35
# kl:0.01150,lr_multiplier:0.132,loss:3.724451780319214,entropy:3.1117496490478516,explained_var_old:0.350,explained_var_new:0.371
# batch i:170, episode_len:24
# kl:0.01571,lr_multiplier:0.132,loss:3.7371838092803955,entropy:3.0650203227996826,explained_var_old:0.301,explained_var_new:0.329
# batch i:171, episode_len:14
# kl:0.01297,lr_multiplier:0.132,loss:3.7753069400787354,entropy:3.137115478515625,explained_var_old:0.343,explained_var_new:0.368
# batch i:172, episode_len:23
# kl:0.01540,lr_multiplier:0.132,loss:3.704256534576416,entropy:3.1483426094055176,explained_var_old:0.332,explained_var_new:0.352
# batch i:173, episode_len:29
# kl:0.00888,lr_multiplier:0.198,loss:3.707094669342041,entropy:3.070871353149414,explained_var_old:0.353,explained_var_new:0.379
# batch i:174, episode_len:21
# kl:0.02045,lr_multiplier:0.198,loss:3.7192490100860596,entropy:3.0400595664978027,explained_var_old:0.286,explained_var_new:0.331
# batch i:175, episode_len:26
# kl:0.02184,lr_multiplier:0.198,loss:3.665999412536621,entropy:3.0790042877197266,explained_var_old:0.372,explained_var_new:0.405
# batch i:176, episode_len:35
# kl:0.02247,lr_multiplier:0.198,loss:3.534864664077759,entropy:2.9724464416503906,explained_var_old:0.382,explained_var_new:0.417
# batch i:177, episode_len:25
# kl:0.02479,lr_multiplier:0.198,loss:3.6200857162475586,entropy:3.0321836471557617,explained_var_old:0.316,explained_var_new:0.347
# batch i:178, episode_len:23
# kl:0.03490,lr_multiplier:0.198,loss:3.6218395233154297,entropy:2.910090446472168,explained_var_old:0.322,explained_var_new:0.357
# batch i:179, episode_len:30
# kl:0.01998,lr_multiplier:0.198,loss:3.5498390197753906,entropy:3.007018566131592,explained_var_old:0.380,explained_var_new:0.422
# batch i:180, episode_len:29
# kl:0.02948,lr_multiplier:0.198,loss:3.552661418914795,entropy:2.9518892765045166,explained_var_old:0.333,explained_var_new:0.357
# batch i:181, episode_len:27
# kl:0.02585,lr_multiplier:0.198,loss:3.530242443084717,entropy:3.0081324577331543,explained_var_old:0.428,explained_var_new:0.453
# batch i:182, episode_len:27
# kl:0.03492,lr_multiplier:0.198,loss:3.5632598400115967,entropy:2.9824821949005127,explained_var_old:0.388,explained_var_new:0.412
# batch i:183, episode_len:21
# kl:0.02460,lr_multiplier:0.198,loss:3.494058609008789,entropy:2.974562168121338,explained_var_old:0.411,explained_var_new:0.440
# batch i:184, episode_len:22
# kl:0.02351,lr_multiplier:0.198,loss:3.6128673553466797,entropy:2.9864370822906494,explained_var_old:0.353,explained_var_new:0.384
# batch i:185, episode_len:17
# kl:0.02101,lr_multiplier:0.198,loss:3.5719354152679443,entropy:2.9800708293914795,explained_var_old:0.357,explained_var_new:0.380
# batch i:186, episode_len:17
# kl:0.01885,lr_multiplier:0.198,loss:3.5670166015625,entropy:2.9350621700286865,explained_var_old:0.376,explained_var_new:0.396
# batch i:187, episode_len:30
# kl:0.02002,lr_multiplier:0.198,loss:3.565450668334961,entropy:2.943746566772461,explained_var_old:0.331,explained_var_new:0.365
# batch i:188, episode_len:18
# kl:0.01789,lr_multiplier:0.198,loss:3.5865511894226074,entropy:2.9106335639953613,explained_var_old:0.237,explained_var_new:0.267
# batch i:189, episode_len:22
# kl:0.02205,lr_multiplier:0.198,loss:3.5900771617889404,entropy:2.934720754623413,explained_var_old:0.295,explained_var_new:0.330
# batch i:190, episode_len:18
# kl:0.01502,lr_multiplier:0.198,loss:3.761523723602295,entropy:3.033165454864502,explained_var_old:0.243,explained_var_new:0.282
# batch i:191, episode_len:27
# kl:0.02452,lr_multiplier:0.198,loss:3.584151268005371,entropy:2.9480295181274414,explained_var_old:0.315,explained_var_new:0.333
# batch i:192, episode_len:20
# kl:0.01667,lr_multiplier:0.198,loss:3.5759470462799072,entropy:2.9335083961486816,explained_var_old:0.280,explained_var_new:0.329
# batch i:193, episode_len:37
# kl:0.02628,lr_multiplier:0.198,loss:3.5127294063568115,entropy:2.811673879623413,explained_var_old:0.306,explained_var_new:0.352
# batch i:194, episode_len:41
# kl:0.01764,lr_multiplier:0.198,loss:3.5585403442382812,entropy:2.9033799171447754,explained_var_old:0.253,explained_var_new:0.281
# batch i:195, episode_len:18
# kl:0.02206,lr_multiplier:0.198,loss:3.527451276779175,entropy:2.839456081390381,explained_var_old:0.321,explained_var_new:0.359
# batch i:196, episode_len:20
# kl:0.01887,lr_multiplier:0.198,loss:3.5471580028533936,entropy:2.906980037689209,explained_var_old:0.297,explained_var_new:0.329
# batch i:197, episode_len:20
# kl:0.02344,lr_multiplier:0.198,loss:3.588181972503662,entropy:2.947565793991089,explained_var_old:0.306,explained_var_new:0.338
# batch i:198, episode_len:27
# kl:0.03032,lr_multiplier:0.198,loss:3.4100613594055176,entropy:2.8331727981567383,explained_var_old:0.351,explained_var_new:0.381
# batch i:199, episode_len:35
# kl:0.02864,lr_multiplier:0.198,loss:3.4203333854675293,entropy:2.8345348834991455,explained_var_old:0.381,explained_var_new:0.410
# batch i:200, episode_len:15
# kl:0.02542,lr_multiplier:0.198,loss:3.5032739639282227,entropy:2.8991665840148926,explained_var_old:0.340,explained_var_new:0.368
# current self-play batch: 200
#
# quit
